# %% [markdown]
# # Assignment-1

# %%
#1 Switch Values of two integers
n1 = 20
n2 = 30

print(f"Before Swapping n1 ={n1} and n2 = {n2}")
n = n1
n1 = n2
n2 = n
print(f"After Swapping n1 = {n1} and n2= {n2}")
# Out:
# Before Swapping n1 =20 and n2 = 30
# After Swapping n1 = 30 and n2= 20

# %%
#2 Switch two strings
char1 = "hello"
char2 = "java"

print(f"Before Swapping char1 = {char1} and char2 = {char2}")
char = char1
char1 = char2
char2 = char
print(f"After Swapping char1 = {char1} and char2= {char2}")
# Out:
# Before Swapping char1 = hello and char2 = java
# After Swapping char1 = java and char2= hello

# %%
#3 Switch one string and one integer
n1 = 200
char2 = "java"

print(f"Before Swapping n1 = {n1} and char2 = {char2}")
swap = n1
n1 = char2
char2 = swap
print(f"After Swapping n1 = {n1} and char2= {char2}")
# Out:
# Before Swapping n1 = 200 and char2 = java
# After Swapping n1 = java and char2= 200

# %%
#5 Update Balance after deposite
current_balance = 10000
deposite_balance = 5000

print(f"Before Deposite current balance is {current_balance}")
print(f"After Deposite current balance is {current_balance + deposite_balance}")
# Out:
# Before Deposite current balance is 10000
# After Deposite current balance is 15000

# %%
#6 Update Balance After Withdrawal
current_balance = 12000
withdrawal = 3000

print(f"Before withdrawal current balance is {current_balance}")
print(f"After withdrawal current balance is {current_balance - withdrawal}")
# Out:
# Before withdrawal current balance is 12000
# After withdrawal current balance is 9000

# %%
#7 Increse shopping cart item by 3
cart_items = 5
increase_item = 3

print(f"Before increase shopping cart item is {cart_items}")
print(f"After increase shopping cart item is {cart_items*3}")
# Out:
# Before increase shopping cart item is 5
# After increase shopping cart item is 15

# %%
#8 Apply a 20% discount to a price
price = 1000
percentage = 20

discount_price = (price*20)/100
final_price = price - discount_price

print(f"Before discount price is {price}")
print(f"After 20% discount final price is {final_price}")
# Out:
# Before discount price is 1000
# After 20% discount final price is 800.0

# %% [markdown]
# ### Academic Calculations

# %%
#9 Calculate student percentage
total_marks = 500
obtain_marks = int(input("Enter the obtain marks:"))

percentage = (obtain_marks*100)/total_marks
print(f"Percetage of marks is {percentage}%")
# Out:
# Percetage of marks is 60.0%

# %%
#10 total average of 4 students
sub1 = int(input("Enter first subject number:"))
sub2 = int(input("Enter second subject number:"))
sub3 = int(input("Enter third subject number:"))
sub4 = int(input("Enter fourth subject number:"))

total = sub1 + sub2 + sub3 + sub4
average = (sub1 + sub2 + sub3 + sub4)/4

print(f"Total marks of all subject:{total}")
print(f"Average marks of all subject:{average}")
# Out:
# Total marks of all subject:100
# Average marks of all subject:25.0

# %%
#11 average of 3 numbers
num1 = 25
num2 = 35
num3 = 45

avg = (num1+num2+num3)/3
print(f"Average of these numbers is:{avg}")
# Out:
# Average of these numbers is:35.0

# %%
#12 Calculate profit and loss percentage
cost_price = 500
selling_price = 600

profit = selling_price - cost_price
loss = cost_price - selling_price

profit_percentage = (profit/cost_price)*100
loss_percentage = (loss/cost_price)*100

print(f"Profit percentage: {profit_percentage}%")
print(f"Profit percentage: {loss_percentage}%")
# Out:
# Profit percentage: 20.0
# Profit percentage: -20.0

# %%
#13 Calculate simple interest
principal = 10000
rate = 5
time = 2

simple_interest = (principal*rate*time)/100
print(f"Simple Interest is: {simple_interest}")
# Out:
# Simple Interest is: 1000.0

# %%
#14 Calculate compound interest
principal = 10000
rate = 5
time = 2

compound_interest = principal*(1+rate/100)**time
print(f"Compound Interest: {compound_interest}")
# Out:
# Compound Interest: 11025.0

# %%
#15 Find Tax on Income
income = 500000
tax_rate = 10

tax_on_income = 500000*(10/100)
print(f"Tax on income is : {tax_on_income}")
# Out:
# Tax on income is : 50000.0

# %%
#16 Percentage increase or decrease
initial_value = 200 
final_value = 250

percentage_change = ((final_value-initial_value)/initial_value)*100
print(f"Percentage Change : {percentage_change} so it is increase")
# Out:
# Percentage Change : 25.0 so it is increase

# %% [markdown]
# ### Conversion

# %%
#17 convert bollean to integer
a = True
res = int(a)
print(f"Convert boolean to integer value is :{res}")
# Out:
# Convert boolean to integer value is :1

# %%
#18 Convert float to string
a = 45.67
res = str(a)
print(f"Convert float to string value is : {res}")
# Out:
# Convert float to string value is : 45.67

# %%
#19 Convert 20 degreee C to fahrenheit
celsius_value = 20

f = (celsius_value*(9/5))+32
print(f"Celsius to fahrenheit value is: {f}")
# Out:
# Celsius to fahrenheit value is: 68.0

# %%
#20 convert 50 degree F to Celsius
fahrenheit_value = 50

c = (5/9)*(fahrenheit_value - 32)
print(f"Fahrenheit to celsius value is: {c}")
# Out:
# Fahrenheit to celsius value is: 10.0

# %%
#21 convert integer to binary
a = 25
res = bin(a)
print(f"Integer to binary is {res}")
# Out:
# Integer to binary is 0b11001

# %%
#21 Find area of triangle
base = 10 
height = 6

area_of_triangle = (base*height)/2
print(f"Area of triangle is {area_of_triangle}")
# Out:
# Area of triangle is 30.0

# %%
#22 Calculate perimeter of a square
side = 9

p = 4*side
print(f"Perimeter of a square is: {p}")
# Out:
# Perimeter of a square is: 36

# %%
#23 Calculate diameter of a circle
radius = 14

d = 2*radius
print(f"Diameter of a circle is :{d}")
# Out:
# Diameter of a circle is :28

# %%
#24 Calculate volume of cube
side = 5

v = side**3
print(f"Volume of cube is : {v}")
# Out:
# Volume of cube is : 125

# %%
#25 Calculate surface area of a cuboid
l = 4
b = 3
h = 2

area = 2*((l*b)+(b*h)+(h*l))
print(f"Surface area of a cuboid : {area}")
# Out:
# Surface area of a cuboid : 52

# %%
#26 square of sum (x+y)**2
x = 5
y = 7

square = (x**2 + y**2 + 2*x*y)
print(f"Square of sum is : {square}")
# Out:
# Square of sum is : 144

# %%
#27 Simplify expression x**2 - 4*x + 4
x = 3
res = (x**2 - 4*x + 4)
print(f"Simplify expression value is: {res}")
# Out:
# Simplify expression value is: 1

# %%
#28 Evaluate (a+b)(a-b)
a = 6
b = 2

res = (a+b)*(a-b)
print(f"Evaluate result of the espression is : {res}")
# Out:
# Evaluate result of the espression is : 32

# %%
#29 Sum cubes a**3 + b**3
a = 1
b = 2

res = (a**3 + b**3)
print(f"Sum of cubes is: {res}")
# Out:
# Sum of cubes is: 9

# %%
#30 simplify (x-y)**2
x = 10
y = 6

res = (x**2 + y**2 - 2*x*y)
print(f"Simplify expression result is: {res}")
# Out:
# Simplify expression result is: 16

# %%
#31 Difference of cubes x**3 - y**3
x = 4
y = 1

res = (x**3 - y**3)
print(f"Difference of cubes is: {res}")
# Out:
# Difference of cubes is: 63

# %% [markdown]
# ### String Operation

# %%
#32 
name = input("Enter your name:")
age = input("Enter your age:")
city = input("Enter your city:")
hobby = input("Enter your hobby:")

print(f"Meet {name}, a {age}-year-old enthusiast from {city}.\nWhen not busy with daily tasks, {name} loves spending time {hobby}.\nLife in {city} keeps {name} energetic and curious every single day.\nWith coading as a passion, the future looks and inspiring for \n{name} in the {city} City.")
# Out:
# Meet Dev, a 25-year-old enthusiast from Jaipur.
# When not busy with daily tasks, Dev loves spending time Cooking.
# Life in Jaipur keeps Dev energetic and curious every single day.
# With coading as a passion, the future looks and inspiring for
# Dev in the Jaipur City.

# %%
#33
full_name = input("Enter your Full Name:")
profession = input("Enter your Profession:")
favorite_quote = input("Enter your Favorite Quote:")
years_of_experience = input("Enter your Years of Experience:")

print(f"Name : {full_name}")
print(f"Profession : {profession}")
print(f"Years of Experience : {years_of_experience} Years")
print(f"Quote : {favorite_quote}")
# Out:
# Name : kaushik singh
# Profession : data sciencet
# Years of Experience : 20 Years
# Quote : This is the quote that is used

# %%
#34
movie_name = input("Enter the Movie Name:")
viewer_name = input("Enter your Viewer Name:")
seat_number = input("Enter your Seat Number:")
show_time = input("Enter your Show Time:")

print(f"Movie : {movie_name}")
print(f"Name : {viewer_name}")
print(f"Seat No : {seat_number}")
print(f"Time : {show_time}")
# Out:
# Movie : Narcos
# Name : Kaushik
# Seat No : 20
# Time : 3:45 pm
