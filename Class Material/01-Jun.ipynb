# %% [markdown]
# ### Operator and conditional statement

# %% [markdown]
# #### Operator
# 1. Airthmatic Operator (+, -, *, /, **, //, %)
# 2. Comparsion/relation Operator (>, <, >=, <=, ==, !=)
# 3. Logical Operator (and, or, not)
# 4. Membership Operator (in, not in)
# 5. Identity Operator (is, is not)
# 6. Assignment Operator (+=, -+, *=)
# 7. Bitwise Operator

# %%
#2 Comparsion Operator all the used by self 
a_age = 55
b_age = 56

if a_age >= b_age:
    print("Yes")
else:
    print("No")
# Out:
# No

# %%
#Ex1- WAP to check odd and even
num = int(input("Enter any number: "))

if (num%2 == 0):
    print("The given number is Even.")
else:
    print("The given number is ODD.")
# Out:
# The given number is ODD.

# %%
#Ex2 WAP to check eligbility for voating.
age = int(input("Enter your age:"))

if age >= 18:
    print("You are eligbile for vote.")
else:
    print("You are not eligble for vote you need to wait untill you are not 18 years old.")
# Out:
# You are not eligble for vote you need to wait untill you are not 18 years old.

# %%
#Ex3 WAP to check eligbility for pm.
age = int(input("Enter your age:"))

if age >= 25:
    print("Yor are eligbile for PM.")
else:
    print("You are not eligble for PM.")
# Out:
# You are not eligble for PM.

# %%
#ex-4
# Wap check a number given by user is completely divide by 2 and 3

num = int(input("Enter any number:"))

if num%2 == 0 and num%3 == 0:
    print("Number is completely divide.")
else:
    print("Number is not completely divide")
# Out:
# Number is not completely divide
