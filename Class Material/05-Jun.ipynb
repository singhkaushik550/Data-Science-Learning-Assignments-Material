# %%
# traversing on string
str1 ="python programming"
for i in range(len(str1)):
    print(str1[i],i)
# Out:
# p 0
# y 1
# t 2
# h 3
# o 4
# n 5
#   6
# p 7
# r 8
# o 9
# g 10
# r 11
# a 12
# m 13
# m 14
# i 15
# n 16
# g 17

# %%
# WAP to count the total number of vowels
str = "python programming"
count = 0
for i in str1:
    if i == "a" or i == "e" or i == "i" or i == "o" or i == "u":
        count += 1
print(count)
# Out:
# 4

# %%
# WAP to reverse the string pass by user

str = "kaushik"
rev = str[::-1]
print (rev)
# Out:
# kihsuak

# %%
str = 'kaushik'
rev_str = ""

for char in str:
    rev_str = char + rev_str
print(rev_str)
# Out:
# kihsuak

# %%
# WAP to find the character from string "this is python programming"
str = "this is python programming"
find_char = input("Enter the character that you want to find").strip().lower()

for char in str:
    if char in find_char:
        print(f"The character is find")
        break
else:
    print("Invalid Character")
# Out:
# Invalid Character

# %%
# WAP to count how many consonants
str = input("Enter text:").strip().lower()
count = 0
for i in str1:
    if i != "a" and i != "e" and i != "i" and i != "o" and i != "u":
        count += 1
print(f"Total consonants are : {count}")
# Out:
# Total consonants are : 14
