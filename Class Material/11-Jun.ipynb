# %%
string = "kaushik"
count = 0
for i in string:
    print(count,i)
    count = count+1
# Out:
# 0 k
# 1 a
# 2 u
# 3 s
# 4 h
# 5 i
# 6 k

# %%
string = "kaushik"

for ch in range (len(string)):
    print(ch, string[ch])
# Out:
# 0 k
# 1 a
# 2 u
# 3 s
# 4 h
# 5 i
# 6 k
