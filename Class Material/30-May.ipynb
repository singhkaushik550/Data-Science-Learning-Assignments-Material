# %% [markdown]
# ## Strings

# %%
# multiline string
# use instead of this use (''' ahhhbd ''')
text = """"This is the multiline string that i willl used for writing the multine content or anything that you want you can write easily.😙"""
print(text)
# Out:
# "This is the multiline string that i willl used for writing the multine content or anything that you want you can write easily.😙

# %%
# WAP to take digit from user input print only last digit.
i = int(input("Enter your digit: "))
res = i%10
print(res)
# Out:
# 5

# %%
# Operator and conditional statement
