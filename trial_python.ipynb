# %%
Rajneesh = int(input("Welcome Kaushik"))
if Rajneesh%4 == 0:
    if Rajneesh%100 ==0:
        if Rajneesh%400 == 0:
            print(Rajneesh,"Good")
        else:
            print(Rajneesh,"Not Good")
    else: 
        print(Rajneesh,"Good")
else:
    print(Rajneesh,"Not Good")
# Out:
# 2021 Not Good

# %%
Shalu = int(input("Enter OOH shit:")) 
Rishav = Shalu
Devendra = 0

while Shalu > 0:
    Ashi = Shalu%10 
    Devendra = Devendra*10+Ashi
    Shalu = Shalu//10
    

if Rishav == Devendra:
    print("The ooh shit is a good thing")
else:
    print("The ooh shit is not a good thing")
# Out:
# The ooh shit is a good thing

# %%
Shalu = int(input("Tea:"))
Kritika = int(input("coffee:"))
Rahul = 1
Kaushik = 1
Shivani = 1

for i in range (1,Shalu+1):
    Rahul *= i
    
for i in range(1,Kritika+1):
    Kaushik *= i
    
for i in range(1,Shalu-Kritika+1):
    Shivani *= i
    
Kapil = Rahul//(Kaushik*Shivani)
print("nCr =",Kapil)
# Out:
# nCr = 252
